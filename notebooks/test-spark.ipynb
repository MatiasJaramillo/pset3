# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("P3 Infra Test").getOrCreate()

df = spark.createDataFrame([
    (1, "yellow"),
    (2, "green")
], ["id", "service_type"])

df.show()
# Out:
# +---+------------+
# | id|service_type|
# +---+------------+
# |  1|      yellow|
# |  2|       green|
# +---+------------+
